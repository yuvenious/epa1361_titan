# %%
import numpy as np
import networkx as nx
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
pd.read_excel('./data/dikeIjssel.xlsx', dtype = object)
# Out:
#   OBJECTID NodeName prec_node   km branch        type dikelevel hground  \
# 0        0      A.0       NaN  NaN    NaN    upstream       NaN     NaN
# 1        1      A.1       A.0  903      A        dike   931.669     9.5
# 2        2      A.2       A.1  922      A        dike   784.469     7.7
# 3        3      A.3       A.2  932      A        dike       909     6.6
# 4        4      A.4       A.3  940      A        dike   678.626     5.6
# 5        5      A.5       A.4  947      A        dike    736.45     4.8
# 6        6      A.6       A.5  NaN      A  downstream       NaN     NaN
#
#   dike_ring traject_id      c     b   lambda traj_ratio
# 0       NaN        NaN    NaN   NaN      NaN        NaN
# 1        49          2  28.57   0.2  0.00336          1
# 2        52          1  124.2  0.61  0.00336    0.27444
# 3        50          2  18.58  0.04  0.00336          1
# 4        51          1   5.41  0.05  0.00336          1
# 5        53          1  22.71  0.07  0.00336          1
# 6       NaN        NaN    NaN   NaN      NaN        NaN

# %%
df = pd.read_excel('./data/dikeIjssel.xlsx', dtype = object)
df = df.set_index('NodeName')
df
# Out:
#          OBJECTID prec_node   km branch        type dikelevel hground  \
# NodeName
# A.0             0       NaN  NaN    NaN    upstream       NaN     NaN
# A.1             1       A.0  903      A        dike   931.669     9.5
# A.2             2       A.1  922      A        dike   784.469     7.7
# A.3             3       A.2  932      A        dike       909     6.6
# A.4             4       A.3  940      A        dike   678.626     5.6
# A.5             5       A.4  947      A        dike    736.45     4.8
# A.6             6       A.5  NaN      A  downstream       NaN     NaN
#
#          dike_ring traject_id      c     b   lambda traj_ratio
# NodeName
# A.0            NaN        NaN    NaN   NaN      NaN        NaN
# A.1             49          2  28.57   0.2  0.00336          1
# A.2             52          1  124.2  0.61  0.00336    0.27444
# A.3             50          2  18.58  0.04  0.00336          1
# A.4             51          1   5.41  0.05  0.00336          1
# A.5             53          1  22.71  0.07  0.00336          1
# A.6            NaN        NaN    NaN   NaN      NaN        NaN

# %%
nodes = df.to_dict('index')
nodes
# Out:
# {'A.0': {'OBJECTID': 0,
#   'b': nan,
#   'branch': nan,
#   'c': nan,
#   'dike_ring': nan,
#   'dikelevel': nan,
#   'hground': nan,
#   'km': nan,
#   'lambda': nan,
#   'prec_node': nan,
#   'traj_ratio': nan,
#   'traject_id': nan,
#   'type': 'upstream'},
#  'A.1': {'OBJECTID': 1,
#   'b': 0.2,
#   'branch': 'A',
#   'c': 28.57,
#   'dike_ring': 49,
#   'dikelevel': 931.668701172,
#   'hground': 9.5,
#   'km': 903,
#   'lambda': 0.00336,
#   'prec_node': 'A.0',
#   'traj_ratio': 1,
#   'traject_id': 2,
#   'type': 'dike'},
#  'A.2': {'OBJECTID': 2,
#   'b': 0.61,
#   'branch': 'A',
#   'c': 124.2,
#   'dike_ring': 52,
#   'dikelevel': 784.469238281,
#   'hground': 7.7,
#   'km': 922,
#   'lambda': 0.00336,
#   'prec_node': 'A.1',
#   'traj_ratio': 0.27443976905763773,
#   'traject_id': 1,
#   'type': 'dike'},
#  'A.3': {'OBJECTID': 3,
#   'b': 0.04,
#   'branch': 'A',
#   'c': 18.58,
#   'dike_ring': 50,
#   'dikelevel': 909,
#   'hground': 6.6,
#   'km': 932,
#   'lambda': 0.00336,
#   'prec_node': 'A.2',
#   'traj_ratio': 1,
#   'traject_id': 2,
#   'type': 'dike'},
#  'A.4': {'OBJECTID': 4,
#   'b': 0.05,
#   'branch': 'A',
#   'c': 5.41,
#   'dike_ring': 51,
#   'dikelevel': 678.625549316,
#   'hground': 5.6,
#   'km': 940,
#   'lambda': 0.00336,
#   'prec_node': 'A.3',
#   'traj_ratio': 1,
#   'traject_id': 1,
#   'type': 'dike'},
#  'A.5': {'OBJECTID': 5,
#   'b': 0.07,
#   'branch': 'A',
#   'c': 22.71,
#   'dike_ring': 53,
#   'dikelevel': 736.450012207,
#   'hground': 4.8,
#   'km': 947,
#   'lambda': 0.00336,
#   'prec_node': 'A.4',
#   'traj_ratio': 1,
#   'traject_id': 1,
#   'type': 'dike'},
#  'A.6': {'OBJECTID': 6,
#   'b': nan,
#   'branch': 'A',
#   'c': nan,
#   'dike_ring': nan,
#   'dikelevel': nan,
#   'hground': nan,
#   'km': nan,
#   'lambda': nan,
#   'prec_node': 'A.5',
#   'traj_ratio': nan,
#   'traject_id': nan,
#   'type': 'downstream'}}

# %%
G = nx.MultiDiGraph()
for key, attr in nodes.items():
    G.add_node(key, **attr)

nx.draw_circular(G,
    node_color = "lightblue",
    node_size=2000,
    with_labels=True)

# %%
# A.0 and A.6 are respectively upstream and downstream
dike_list = df['type'][df['type'] == 'dike'].index.values
dike_list
# Out:
# array(['A.1', 'A.2', 'A.3', 'A.4', 'A.5'], dtype=object)

# %%
# dike_branches = {k: df[df['branch'] == k].index.values for k in np.unique(df['branch'])}
dike_branches = {k: df[df['branch'] == k].index.values for k in df['branch'].unique()}
dike_branches
# Out:
# {'A': array(['A.1', 'A.2', 'A.3', 'A.4', 'A.5', 'A.6'], dtype=object),
#  nan: array([], dtype=object)}

# %%
df["branch"].unique()
# Out:
# array([nan, 'A'], dtype=object)

# %%
pd.read_excel('./data/fragcurves/frag_curves.xlsx', header = None, index_col = 0).transpose().head()
# Out:
# 0   wl      52001013      50001010      51002006      52002004      53003009  \
# 1  0.0  6.680000e-20  6.680000e-20  6.680000e-20  6.680000e-20  6.680000e-20
# 2  0.1  6.680000e-20  6.680000e-20  6.680000e-20  6.680000e-20  6.680000e-20
# 3  0.2  6.680000e-20  6.680000e-20  6.680000e-20  6.680000e-20  6.680000e-20
# 4  0.3  6.680000e-20  6.680000e-20  6.680000e-20  6.680000e-20  6.680000e-20
# 5  0.4  6.680000e-20  6.680000e-20  6.680000e-20  6.680000e-20  6.680000e-20
#
# 0      53003008
# 1  6.680000e-20
# 2  6.680000e-20
# 3  6.680000e-20
# 4  6.680000e-20
# 5  6.680000e-20

# %%
frag_curves = pd.read_excel('./data/fragcurves/frag_curves.xlsx', header = None, index_col = 0).transpose()

# %%
for col in frag_curves.columns[1:]:
    plt.plot(frag_curves["wl"], frag_curves[col], label = col)
plt.legend()

# %%
pd.read_excel('./data/fragcurves/calfactors_pf1250.xlsx').head()
# Out:
#          mean
# A.1  1.177979
# A.2  0.043945
# A.3 -1.125488
# A.4 -1.674805
# A.5 -2.324219

# %%
calibration_factors = pd.read_excel('./data/fragcurves/calfactors_pf1250.xlsx')

# %%
pd.read_excel('./data/rfr_strategies.xlsx', index_col = 0, names = range(5))
# Out:
#                   0       1      2       3       4
# Project name
# A.1            0.19    0.17    NaN     NaN     NaN
# A.2             NaN     NaN   0.05    0.02     NaN
# A.3             NaN     NaN   0.11    0.04    0.01
# A.4             NaN     NaN    NaN    0.06    0.05
# A.5             NaN     NaN    NaN    0.12     NaN
# costs_1e6     84.60  217.80  30.70  121.20  256.10

# %%
G.node["A.1"]
# Out:
# {'OBJECTID': 1,
#  'b': 0.2,
#  'branch': 'A',
#  'c': 28.57,
#  'dike_ring': 49,
#  'dikelevel': 931.668701172,
#  'hground': 9.5,
#  'km': 903,
#  'lambda': 0.00336,
#  'prec_node': 'A.0',
#  'traj_ratio': 1,
#  'traject_id': 2,
#  'type': 'dike'}

# %%
def to_dict_dropna(data):
    return dict((str(k), v.dropna().to_dict()) for k, v in pd.compat.iteritems(data))

# %%
# Upload room for the river projects:
G.add_node('RfR_projects', **to_dict_dropna(
            pd.read_excel('./data/rfr_strategies.xlsx', index_col = 0, 
                            names = range(5))))
G.node['RfR_projects']['type'] = 'measure'

# Upload evacuation policies:
G.add_node('EWS', **pd.read_excel('./data/EWS.xlsx').to_dict())
G.node['EWS']['type'] = 'measure'

# %%
G.node["RfR_projects"]
# Out:
# {'0': {'A.1': 0.19, 'costs_1e6': 84.6},
#  '1': {'A.1': 0.17, 'costs_1e6': 217.8},
#  '2': {'A.2': 0.05, 'A.3': 0.11, 'costs_1e6': 30.7},
#  '3': {'A.2': 0.02, 'A.3': 0.04, 'A.4': 0.06, 'A.5': 0.12, 'costs_1e6': 121.2},
#  '4': {'A.3': 0.01, 'A.4': 0.05, 'costs_1e6': 256.1},
#  'type': 'measure'}

# %%
G.node["EWS"]
# Out:
# {'days': {0: 0, 1: 1, 2: 2, 3: 3, 4: 4},
#  'evacuees': {0: 0.0, 1: 0.64, 2: 0.85, 3: 0.88, 4: 0.88},
#  'type': 'measure'}

# %%
nx.draw_circular(G,
    node_color = "lightblue",
    node_size=2000,
    with_labels=True)

# %%
pd.read_excel('./data/Muskingum/params.xlsx')
# Out:
#             K         X        C1        C2        C3
# A.0  0.378929 -1.055501  0.703704  0.078224  0.218072
# A.1  0.101616 -3.846220  0.897611  0.109992 -0.007603
# A.2  0.189157 -1.789507  0.815934  0.157157  0.026909
# A.3  0.303710 -0.013471  0.624029  0.613900 -0.237929
# A.5  0.779782  0.074716  0.361629  0.457023  0.181347
# A.4  0.303710 -0.013471  0.624029  0.613900 -0.237929

# %%
Muskingum_params = pd.read_excel('./data/Muskingum/params.xlsx')

# %%
def Lookuplin(MyFile, inputcol, searchcol, inputvalue):
    ''' Linear lookup function '''
    
    minTableValue=min(MyFile[:,inputcol])
    maxTableValue=max(MyFile[:,inputcol])
    
    if inputvalue >= maxTableValue: 
        inputvalue=maxTableValue-0.01 
    if inputvalue < minTableValue:
        inputvalue=minTableValue+0.01
        
    A = max(MyFile[MyFile[:,inputcol] <= inputvalue,inputcol])
    B = min(MyFile[MyFile[:,inputcol] > inputvalue,inputcol]) 
    C = max(MyFile[MyFile[:,inputcol] == A,searchcol]) 
    D = min(MyFile[MyFile[:,inputcol] == B,searchcol])
    
    outpuvalue = C-((D-C)*((inputvalue-A)/(A-B)))*1.0
    
    return outpuvalue

# %%
for dike in dike_list:
        # Assign fragility curves, assuming it's the same shape for every location
        dikeid = 50001010
        G.node[dike]['f'] = np.column_stack((frag_curves.loc[:,'wl'].values, 
                                             frag_curves.loc[:,dikeid].values))
        # Adjust fragility curves
        G.node[dike]['f'][:,0] += calibration_factors.loc[dike].values
        
        # Determine the level of the dike        
        G.node[dike]['dikelevel'] = Lookuplin(G.node[dike]['f'], 1, 0, 0.5)
        
        # Assign stage-discharge relationships
        filename = './data/rating_curves/{}_ratingcurve_new.txt'.format(dike)               
        G.node[dike]['r'] = np.loadtxt(filename)
        
        # Assign losses per location:
        name = './data/losses_tables/{}_lossestable.xlsx'.format(dike)
        G.node[dike]['table'] = pd.read_excel(name).values
        
        # Assign Muskingum paramters:        
        G.node[dike]['C1'] = Muskingum_params.loc[G.node[dike]['prec_node'], 'C1']
        G.node[dike]['C2'] = Muskingum_params.loc[G.node[dike]['prec_node'], 'C2']
        G.node[dike]['C3'] = Muskingum_params.loc[G.node[dike]['prec_node'], 'C3']

# %%
dike
# Out:
# 'A.5'

# %%
G.node["A.2"]
# Out:
# {'C1': 0.8976112018759458,
#  'C2': 0.1099915720737832,
#  'C3': -0.007602773949729169,
#  'OBJECTID': 2,
#  'b': 0.61,
#  'branch': 'A',
#  'c': 124.2,
#  'dike_ring': 52,
#  'dikelevel': 9.65500527692471,
#  'f': array([[4.39453125e-02, 6.68000000e-20],
#         [1.43945313e-01, 6.68000000e-20],
#         [2.43945313e-01, 6.68000000e-20],
#         [3.43945312e-01, 6.68000000e-20],
#         [4.43945313e-01, 6.68000000e-20],
#         [5.43945312e-01, 6.68000000e-20],
#         [6.43945312e-01, 6.68000000e-20],
#         [7.43945312e-01, 6.68000000e-20],
#         [8.43945313e-01, 6.68000000e-20],
#         [9.43945313e-01, 6.68000000e-20],
#         [1.04394531e+00, 6.68000000e-20],
#         [1.14394531e+00, 6.68000000e-20],
#         [1.24394531e+00, 6.68000000e-20],
#         [1.34394531e+00, 6.68000000e-20],
#         [1.44394531e+00, 6.68000000e-20],
#         [1.54394531e+00, 6.68000000e-20],
#         [1.64394531e+00, 6.68000000e-20],
#         [1.74394531e+00, 6.68000000e-20],
#         [1.84394531e+00, 6.68000000e-20],
#         [1.94394531e+00, 6.68000000e-20],
#         [2.04394531e+00, 6.68000000e-20],
#         [2.14394531e+00, 6.68000000e-20],
#         [2.24394531e+00, 6.68000000e-20],
#         [2.34394531e+00, 6.68000000e-20],
#         [2.44394531e+00, 6.68000000e-20],
#         [2.54394531e+00, 6.68000000e-20],
#         [2.64394531e+00, 6.68000000e-20],
#         [2.74394531e+00, 6.68000000e-20],
#         [2.84394531e+00, 6.68000000e-20],
#         [2.94394531e+00, 6.68000000e-20],
#         [3.04394531e+00, 6.68000000e-20],
#         [3.14394531e+00, 6.68000000e-20],
#         [3.24394531e+00, 6.68000000e-20],
#         [2995.3   ,    9.9105],
#         [3009.2   ,    9.9252],
#         [3022.5   ,    9.9394],
#         [3035.4   ,    9.9531],
#         [3047.8   ,    9.9664],
#         [3059.6   ,    9.9792],
#         [3070.9   ,    9.9915],
#         [3081.7   ,   10.003 ],
#         [3092.    ,   10.015 ],
#         [3101.7   ,   10.026 ],
#         [3110.8   ,   10.036 ],
#         [3119.2   ,   10.046 ],
#         [3120.9   ,   10.054 ],
#         [3130.4   ,   10.063 ],
#         [3137.9   ,   10.072 ],
#         [3144.2   ,   10.08  ],
#         [3149.6   ,   10.088 ],
#         [3154.4   ,   10.095 ],
#         [3158.5   ,   10.102 ],
#         [3162.2   ,   10.108 ],
#         [3165.3   ,   10.114 ],
#         [3168.    ,   10.12  ],
#         [3170.2   ,   10.125 ],
#         [3172.    ,   10.13  ],
#         [3173.4   ,   10.135 ],
#         [3174.5   ,   10.139 ],
#         [3175.2   ,   10.143 ],
#         [3175.7   ,   10.147 ],
#         [3175.9   ,   10.15  ]]),
#  'table': array([[8.05081000e+09, 1.13096304e+08, 1.40478168e-02, 3.20000000e+01,
#          1.28800000e+09, 2.05190000e+04, 9.25610439e+00],
#         [8.08054000e+09, 1.68698496e+08, 2.08771315e-02, 4.90000000e+01,
#          1.72600000e+09, 2.55890000e+04, 9.61973995e+00],
#         [8.09063000e+09, 1.96033232e+08, 2.42296622e-02, 6.30000000e+01,
#          1.96600000e+09, 2.80680000e+04, 1.01296276e+01]]),
#  'traj_ratio': 0.27443976905763773,
#  'traject_id': 1,
#  'type': 'dike'}

# %%
pd.read_excel('./data/hydrology/wave_shapes.xls').head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.224895  0.214304  0.224283  0.230353  0.219234  0.203512  0.191063
# 1  0.273724  0.264464  0.258063  0.282115  0.334478  0.382453  0.404076
# 2  0.142807  0.111245  0.092054  0.084458  0.083052  0.084611  0.089789
# 3  0.322389  0.291245  0.265126  0.243159  0.226207  0.221248  0.243066
# 4  0.415504  0.401833  0.382493  0.366031  0.353424  0.342985  0.329513
#
#          7         8         9     ...           21        22        23  \
# 0  0.187472  0.224432  0.325306    ...     0.487914  0.416368  0.352370
# 1  0.399115  0.399158  0.416695    ...     0.640464  0.581705  0.517591
# 2  0.117994  0.218844  0.359502    ...     0.405395  0.332713  0.283203
# 3  0.284168  0.366145  0.513192    ...     0.581041  0.493294  0.410575
# 4  0.318997  0.323171  0.351816    ...     0.382906  0.336599  0.359547
#
#          24        25        26        27        28        29        30
# 0  0.298759  0.265009  0.231677  0.219614  0.209021  0.199499  0.190946
# 1  0.471392  0.431625  0.317330  0.298909  0.286502  0.281432  0.281160
# 2  0.253713  0.243552  0.244920  0.251207  0.261964  0.272485  0.276548
# 3  0.311241  0.273744  0.248766  0.231748  0.219752  0.211236  0.204669
# 4  0.435538  0.518725  0.545424  0.535157  0.514660  0.501379  0.493753
#
# [5 rows x 31 columns]

# %%
G.node['A.0']['Qevents_shape'] = pd.read_excel('./data/hydrology/wave_shapes.xls')
G.add_node('discount rate', **{'value': 0})

# %%
nx.draw_circular(G,
    node_color = "lightblue",
    node_size=2000,
    with_labels=True)

# %%
G.node["discount rate"]
# Out:
# {'value': 0}
